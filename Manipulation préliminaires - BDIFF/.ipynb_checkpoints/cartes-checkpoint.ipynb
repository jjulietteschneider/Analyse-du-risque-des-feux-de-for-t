# %% [markdown]
# # Projet Statapp : Feux de forêt

# %% [markdown]
# ## Importations des librairies nécessaires

# %%
import pandas as pd

data = 'combine.csv'

df = pd.read_csv(data, sep=';')

# %%
pip install geopandas matplotlib pandas
# Out:
# Requirement already satisfied: geopandas in /opt/mamba/lib/python3.11/site-packages (0.14.2)
# Requirement already satisfied: matplotlib in /opt/mamba/lib/python3.11/site-packages (3.8.2)
# Requirement already satisfied: pandas in /opt/mamba/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: fiona>=1.8.21 in /opt/mamba/lib/python3.11/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /opt/mamba/lib/python3.11/site-packages (from geopandas) (23.2)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/mamba/lib/python3.11/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /opt/mamba/lib/python3.11/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: pillow>=8 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/mamba/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/mamba/lib/python3.11/site-packages (from pandas) (2023.4)
# Requirement already satisfied: attrs>=19.2.0 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (23.2.0)
# Requirement already satisfied: click~=8.0 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (68.2.2)
# Requirement already satisfied: certifi in /opt/mamba/lib/python3.11/site-packages (from pyproj>=3.3.0->geopandas) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# !pip install requests py7zr geopandas openpyxl tqdm s3fs PyYAML xlrd
# !pip install git+https://github.com/inseefrlab/cartiflette@80b8a5a28371feb6df31d55bcc2617948a5f9b1a
# Out:
# Requirement already satisfied: requests in /opt/mamba/lib/python3.11/site-packages (2.31.0)
# Collecting py7zr
#   Downloading py7zr-0.20.8-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: geopandas in /opt/mamba/lib/python3.11/site-packages (0.14.2)
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/mamba/lib/python3.11/site-packages (4.66.1)
# Requirement already satisfied: s3fs in /opt/mamba/lib/python3.11/site-packages (0.4.2)
# Requirement already satisfied: PyYAML in /opt/mamba/lib/python3.11/site-packages (6.0.1)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/mamba/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.11/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/mamba/lib/python3.11/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/mamba/lib/python3.11/site-packages (from requests) (2023.11.17)
# Collecting texttable (from py7zr)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting pyzstd>=0.15.9 (from py7zr)
#   Downloading pyzstd-0.15.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr)
#   Downloading pyppmd-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr)
#   Downloading pybcj-1.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr)
#   Downloading inflate64-1.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: brotli>=1.1.0 in /opt/mamba/lib/python3.11/site-packages (from py7zr) (1.1.0)
# Requirement already satisfied: psutil in /opt/mamba/lib/python3.11/site-packages (from py7zr) (5.9.8)
# Requirement already satisfied: fiona>=1.8.21 in /opt/mamba/lib/python3.11/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /opt/mamba/lib/python3.11/site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in /opt/mamba/lib/python3.11/site-packages (from geopandas) (2.2.0)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/mamba/lib/python3.11/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /opt/mamba/lib/python3.11/site-packages (from geopandas) (2.0.2)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: botocore>=1.12.91 in /opt/mamba/lib/python3.11/site-packages (from s3fs) (1.34.29)
# Requirement already satisfied: fsspec>=0.6.0 in /opt/mamba/lib/python3.11/site-packages (from s3fs) (2023.12.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/mamba/lib/python3.11/site-packages (from botocore>=1.12.91->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/mamba/lib/python3.11/site-packages (from botocore>=1.12.91->s3fs) (2.8.2)
# Requirement already satisfied: attrs>=19.2.0 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (23.2.0)
# Requirement already satisfied: click~=8.0 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (68.2.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/mamba/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (1.26.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/mamba/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/mamba/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.4)
# Downloading py7zr-0.20.8-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.3 MB/s eta 0:00:00
# Downloading inflate64-1.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 10.3 MB/s eta 0:00:00
# Downloading pybcj-1.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 3.2 MB/s eta 0:00:00
# Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.5 MB/s eta 0:00:00
# Downloading pyppmd-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 kB 21.0 MB/s eta 0:00:00
# Downloading pyzstd-0.15.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 14.8 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, xlrd, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, et-xmlfile, py7zr, openpyxl
# Successfully installed et-xmlfile-1.1.0 inflate64-1.0.0 multivolumefile-0.2.3 openpyxl-3.1.2 py7zr-0.20.8 pybcj-1.0.2 pycryptodomex-3.20.0 pyppmd-1.1.0 pyzstd-0.15.9 texttable-1.7.0 xlrd-2.0.1
# Collecting git+https://github.com/inseefrlab/cartiflette@80b8a5a28371feb6df31d55bcc2617948a5f9b1a
#   Cloning https://github.com/inseefrlab/cartiflette (to revision 80b8a5a28371feb6df31d55bcc2617948a5f9b1a) to /tmp/pip-req-build-xpoz31jg
#   Running command git clone --filter=blob:none --quiet https://github.com/inseefrlab/cartiflette /tmp/pip-req-build-xpoz31jg
#   Running command git rev-parse -q --verify 'sha^80b8a5a28371feb6df31d55bcc2617948a5f9b1a'
#   Running command git fetch -q https://github.com/inseefrlab/cartiflette 80b8a5a28371feb6df31d55bcc2617948a5f9b1a
#   Running command git checkout -q 80b8a5a28371feb6df31d55bcc2617948a5f9b1a
#   Resolved https://github.com/inseefrlab/cartiflette to commit 80b8a5a28371feb6df31d55bcc2617948a5f9b1a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /opt/mamba/lib/python3.11/site-packages (from cartiflette==0.0.1) (6.0.1)
# Collecting appdirs<2.0.0,>=1.4.4 (from cartiflette==0.0.1)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting geopandas<0.13.0,>=0.12.2 (from cartiflette==0.0.1)
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.3 MB/s eta 0:00:0000:01
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /opt/mamba/lib/python3.11/site-packages (from cartiflette==0.0.1) (3.8.2)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.1 in /opt/mamba/lib/python3.11/site-packages (from cartiflette==0.0.1) (3.1.2)
# Collecting owslib<0.29.0,>=0.28.1 (from cartiflette==0.0.1)
#   Downloading OWSLib-0.28.1-py2.py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: py7zr<0.21.0,>=0.20.4 in /opt/mamba/lib/python3.11/site-packages (from cartiflette==0.0.1) (0.20.8)
# Requirement already satisfied: requests<3.0.0,>=2.28.2 in /opt/mamba/lib/python3.11/site-packages (from cartiflette==0.0.1) (2.31.0)
# Collecting s3fs<2024.0.0,>=2023.3.0 (from cartiflette==0.0.1)
#   Downloading s3fs-2023.12.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting topojson<2.0,>=1.5 (from cartiflette==0.0.1)
#   Downloading topojson-1.7-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /opt/mamba/lib/python3.11/site-packages (from cartiflette==0.0.1) (4.66.1)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /opt/mamba/lib/python3.11/site-packages (from cartiflette==0.0.1) (2.0.1)
# Requirement already satisfied: pandas>=1.0.0 in /opt/mamba/lib/python3.11/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (2.2.0)
# Requirement already satisfied: shapely>=1.7 in /opt/mamba/lib/python3.11/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (2.0.2)
# Requirement already satisfied: fiona>=1.8 in /opt/mamba/lib/python3.11/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (1.9.5)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /opt/mamba/lib/python3.11/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (3.6.1)
# Requirement already satisfied: packaging in /opt/mamba/lib/python3.11/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/mamba/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (1.26.3)
# Requirement already satisfied: pillow>=8 in /opt/mamba/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (2.8.2)
# Requirement already satisfied: et-xmlfile in /opt/mamba/lib/python3.11/site-packages (from openpyxl<4.0.0,>=3.1.1->cartiflette==0.0.1) (1.1.0)
# Collecting lxml (from owslib<0.29.0,>=0.28.1->cartiflette==0.0.1)
#   Downloading lxml-5.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: pytz in /opt/mamba/lib/python3.11/site-packages (from owslib<0.29.0,>=0.28.1->cartiflette==0.0.1) (2023.3.post1)
# Requirement already satisfied: texttable in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (3.20.0)
# Requirement already satisfied: pyzstd>=0.15.9 in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (0.15.9)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.1.0)
# Requirement already satisfied: psutil in /opt/mamba/lib/python3.11/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (5.9.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/mamba/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/mamba/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/mamba/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.1) (2023.11.17)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1)
#   Downloading aiobotocore-2.11.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: fsspec==2023.12.2 in /opt/mamba/lib/python3.11/site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (2023.12.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/mamba/lib/python3.11/site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (3.9.1)
# Collecting botocore<1.34.28,>=1.33.2 (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1)
#   Downloading botocore-1.34.27-py3-none-any.whl.metadata (5.7 kB)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1)
#   Downloading wrapt-1.16.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1)
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/mamba/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/mamba/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/mamba/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/mamba/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/mamba/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.3.1)
# Requirement already satisfied: click~=8.0 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (0.7.2)
# Requirement already satisfied: six in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (1.16.0)
# Requirement already satisfied: setuptools in /opt/mamba/lib/python3.11/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (68.2.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/mamba/lib/python3.11/site-packages (from pandas>=1.0.0->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (2023.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/mamba/lib/python3.11/site-packages (from botocore<1.34.28,>=1.33.2->aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.0.1)
# Downloading s3fs-2023.12.2-py3-none-any.whl (28 kB)
# Downloading topojson-1.7-py2.py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 2.7 MB/s eta 0:00:00
# Downloading aiobotocore-2.11.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 kB 11.9 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 44.2 MB/s eta 0:00:0000:0100:01
# Downloading botocore-1.34.27-py3-none-any.whl (11.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 77.9 MB/s eta 0:00:00a 0:00:01
# Downloading wrapt-1.16.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 8.2 MB/s eta 0:00:00
# Building wheels for collected packages: cartiflette
#   Building wheel for cartiflette (pyproject.toml) ... done
#   Created wheel for cartiflette: filename=cartiflette-0.0.1-py3-none-any.whl size=33970 sha256=485fd682c2b6cbea8426492e8f3110d9305a95b0327185b9b236b9bd12cbd10c
#   Stored in directory: /home/onyxia/.cache/pip/wheels/d7/ac/03/1eee3c5602e4bfd7ecf6d2935490351a6f0c6c170393dc868e
# Successfully built cartiflette
# Installing collected packages: appdirs, wrapt, lxml, aioitertools, topojson, owslib, botocore, geopandas, aiobotocore, s3fs, cartiflette
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.29
#     Uninstalling botocore-1.34.29:
#       Successfully uninstalled botocore-1.34.29
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 0.14.2
#     Uninstalling geopandas-0.14.2:
#       Successfully uninstalled geopandas-0.14.2
#   Attempting uninstall: s3fs
#     Found existing installation: s3fs 0.4.2
#     Uninstalling s3fs-0.4.2:
#       Successfully uninstalled s3fs-0.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.34.29 requires botocore<1.35.0,>=1.34.29, but you have botocore 1.34.27 which is incompatible.
# Successfully installed aiobotocore-2.11.1 aioitertools-0.11.0 appdirs-1.4.4 botocore-1.34.27 cartiflette-0.0.1 geopandas-0.12.2 lxml-5.1.0 owslib-0.28.1 s3fs-2023.12.2 topojson-1.7 wrapt-1.16.0

# %%
import cartiflette.s3 as s3

# %%
dep = s3.download_vectorfile_url_all(
    values = "metropole",
    crs = 4326,
    borders = "DEPARTEMENT",
    vectorfile_format="topojson",
    filter_by="FRANCE_ENTIERE",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022)

dep["area"] = dep.to_crs(2154).area
# Out:
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=DEPARTEMENT/crs=4326/FRANCE_ENTIERE=metropole/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 7.17MiB [00:00, 56.1MiB/s]

# %% [markdown]
# ## Carte du nombre de feux par départements entre 2006 et 2022

# %% [markdown]
# dep contient les données gégographiques de la france et de ses départements, df contient nos données sur les feux de forêt.

# %%
dep['nb_feu']=0

# %%
valeurs_a_remplacer = {'1': '01', '2':'02','3': '03', '4': '04', '5':'05', '6':'06', '7':'07', '8':'08', '9':'09'}
df['Département'] = df['Département'].replace(valeurs_a_remplacer)

# %%
counts = df['Département'].value_counts().to_frame().reset_index()

# %% [markdown]
# On donne la valeur 0 pour les départements dont on n'a aucune données

# %%
counts.loc[len(counts)] = ['75', 0]

# %%
counts.loc[len(counts)] = ['92', 0]

# %%
counts.loc[len(counts)] = ['93', 0]

# %%
counts = counts.set_index('Département')

# %% [markdown]
# On ajoute une colonne à dep qui contient le nombre de feux par département

# %%
for i in range(0, 96):
    num = dep.loc[i, 'INSEE_DEP']
    a = counts.loc[num, 'count']
    dep.loc[i, 'nb_feu']=a

# %% [markdown]
# On définit notre échelle de couleur pour la carte

# %%
def couleur(chiffre):
    if chiffre==0:
        return 0
    elif chiffre < 100:
        return 1
    elif chiffre < 500:
        return 2
    elif chiffre < 1500:
        return 3
    else:
        return 4

# %%
dep['categorie']=dep['nb_feu'].apply(couleur)

# %% [markdown]
# Premier test d'affichage

# %%
ax = dep.plot(column = "categorie")
ax.set_axis_off()

# %% [markdown]
# Deuxième essai en personnalisant les couleurs

# %%
cmap = 'YlOrRd'

# Définir la plage de valeurs pour la colormap
vmin, vmax = dep['categorie'].min(), dep['categorie'].max()

# Créer la figure et les axes
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Utiliser la méthode plot avec l'argument cmap pour personnaliser le gradient de couleurs
ax = dep.plot(column="categorie", cmap=cmap, linewidth=0.8, ax=ax, edgecolor='0.8', legend=True, vmin=vmin, vmax=vmax)

# Ajouter un titre à la carte
plt.title('Carte du nombre de feux par département')

# Afficher la carte
plt.show()

# %% [markdown]
# Troisième essai pour personnaliser la légende

# %%
from matplotlib.colors import to_rgba
from matplotlib.patches import Patch

cmap_name = 'OrRd'

# Définir la plage de valeurs pour la colormap
vmin, vmax = dep['categorie'].min(), dep['categorie'].max()

# Créer la figure et les axes
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

# Utiliser la méthode plot avec l'argument cmap pour personnaliser le gradient de couleurs
plot = dep.plot(column="categorie", cmap=cmap_name, linewidth=0.8, ax=ax, edgecolor='0.8', legend=False, vmin=vmin, vmax=vmax)

# Récupérer les couleurs de la colormap
cmap = plt.cm.get_cmap(cmap_name)
colors = [to_rgba(cmap(i)) for i in range(cmap.N)]

# Personnaliser l'affichage de la légende
legend_labels = ['Absence de données', '[1-100[', ']100-500]', ']500-1500]', ']1500-4543]']  # Remplacez par les descriptions de votre choix
legend_patches = [Patch(color=colors[0], label=legend_labels[0]),
                  Patch(color=colors[64], label=legend_labels[1]), Patch(color=colors[128], label=legend_labels[2]), Patch(color=colors[192], label=legend_labels[3]), Patch(color=colors[255], label=legend_labels[4])]

ax.legend(handles=legend_patches, loc='upper left', title='Nombre de feu')

# Masquer les axes
ax.set_axis_off()

# Ajouter un titre à la carte
plt.title('Carte du nombre de feux par département')

# Afficher la carte
plt.show()
# Out:
# /tmp/ipykernel_225/889745226.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap_name)

# %% [markdown]
# ## Ratio surface / feux de forêt entre 2006 et 2022

# %%
# Calculer le nombre d'occurrences par département
counts2 = df['Département'].value_counts().to_frame().reset_index()

# Calculer la somme des surfaces par département
surface_sum = df.groupby('Département')['Surface parcourue (m2)'].sum().reset_index()
surface_sum.columns = ['Département', 'surface']

# Fusionner les deux DataFrames sur la colonne 'Département'
result = pd.merge(counts2, surface_sum, on='Département')

# %%
def rat(count, surface):
    return surface/count if surface!=0 else 0

# %%
result['ratio']=result.apply(lambda row : rat(row['count'], row['surface']), axis=1)

# %% [markdown]
# On ajoute les valeurs manquantes

# %%
result.loc[len(result)] = ['93', 0, 0, 0]

# %%
result.loc[len(result)] = ['92', 0, 0, 0]

# %%
result.loc[len(result)] = ['75', 0, 0, 0]

# %%
result = result.set_index('Département')

# %% [markdown]
# On rajoute une colonne à result pour avoir accès au ration surface brulée / nb de feux

# %%
dep['ratio']=0

# %%
for i in range(0, 96):
    num = dep.loc[i, 'INSEE_DEP']
    a = result.loc[num, 'ratio']
    dep.loc[i, 'ratio']=a
# Out:
# /tmp/ipykernel_225/204975787.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '38783.333333333336' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dep.loc[i, 'ratio']=a

# %% [markdown]
# On définit l'échelle

# %%
def couleur_ratio(chiffre):
    if chiffre/10000 ==0:
        return 0
    elif chiffre/10000 <= 1:
        return 1
    elif chiffre/10000<= 4.6:
        return 2
    elif chiffre/10000 < 10:
        return 3
    else:
        return 4

# %%
dep['cat'] = dep['ratio'].apply(couleur_ratio)

# %%
cmap = 'YlOrRd'

# Définir la plage de valeurs pour la colormap
vmin, vmax = dep['cat'].min(), dep['cat'].max()

# Créer la figure et les axes
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Utiliser la méthode plot avec l'argument cmap pour personnaliser le gradient de couleurs
ax = dep.plot(column="cat", cmap=cmap, linewidth=0.8, ax=ax, edgecolor='0.8', legend=True, vmin=vmin, vmax=vmax)

# Ajouter un titre à la carte
plt.title('Ration surface / nb de feu')

# Afficher la carte
plt.show()

# %% [markdown]
# ## Carte des feux hors norme entre 2006 et 2022

# %%
#on choisit uniquement les feu qui ont parcouru plus 
df_hors_norme = df[df['Surface parcourue (m2)'] > 1*10**7]

# %%
liste = df_hors_norme['Département'].unique().tolist()

# %%
liste.remove('974')

# %%
liste
# Out:
# ['13', '2A', '34', '66', '33', '83', '2B', '84', '11', '29', '49', '07', '48']

# %%
shp_communes = s3.download_vectorfile_url_all(
    crs = 4326,
    values = liste,
    borders="COMMUNE_ARRONDISSEMENT",
    vectorfile_format="topojson",
    filter_by="DEPARTEMENT",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022)
# Out:
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=13/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 866kiB [00:00, 35.1MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=2A/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.51MiB [00:00, 61.6MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=34/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.38MiB [00:00, 63.8MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=66/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 920kiB [00:00, 52.1MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=33/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.47MiB [00:00, 46.0MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=83/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.20MiB [00:00, 46.0MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=2B/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.25MiB [00:00, 62.8MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=84/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 598kiB [00:00, 42.2MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=11/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.29MiB [00:00, 48.4MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=29/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 2.67MiB [00:00, 64.1MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=49/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.02MiB [00:00, 52.1MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=07/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.62MiB [00:00, 67.8MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=48/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.02MiB [00:00, 53.4MiB/s]

# %%
villes = df_hors_norme['Code INSEE'].unique().tolist()

# %%
len(villes)
# Out:
# 30

# %%
shp_communes = shp_communes[shp_communes['INSEE_COM'].isin(villes)]

# %%
# Spécifiez le chemin du fichier GeoJSON des départements
file_path = 'https://static.data.gouv.fr/resources/carte-des-departements-2-1/20191202-212236/contour-des-departements.geojson'

# Chargez les données géographiques avec GeoPandas
france_departments = gpd.read_file(file_path)

# %%
france_departments.plot()
plt.title('Carte des départements de la France')
shp_communes.plot(marker='o', color='red', markersize=5, ax=plt.gca())
plt.show()

# %% [markdown]
# Deuxième test pour avoir un affichage en fonction de la taille du feu

# %%
shp_communes['taille incendie']=0

# %%
shp_communes = shp_communes.reset_index()

# %%
df_hors_norme = df_hors_norme.sort_values(by='Surface parcourue (m2)', ascending=False)
df_hors_norme = df_hors_norme.drop_duplicates(subset='Code INSEE', keep='first')

# %%
df_hors_norme = df_hors_norme.set_index('Code INSEE')

# %%
len(shp_communes['INSEE_COM'])
# Out:
# 42

# %%
df_hors_norme.loc['33225', 'Surface parcourue (m2)']
# Out:
# 125520000

# %%
for i in range(0, 42):
    com = shp_communes.loc[i, 'INSEE_COM']
    taille = df_hors_norme.loc[com, 'Surface parcourue (m2)']
    shp_communes.loc[i, 'taille incendie']=taille

# %%
# Plot du fond de carte
ax = france_departments.plot(figsize=(10, 10), edgecolor='black', color='white')

# Plot des marqueurs de taille proportionnelle
shp_communes.plot(ax=ax, marker='o', color='red', markersize=shp_communes['taille incendie']*10)

# Ajoutez une légende si nécessaire
ax.legend(["Fond de carte", "Marqueurs d'incendie"])

# Affichez la carte 
plt.show()

# %% [markdown]
# On n'a toujours pas l'affichage voulu mais les communes concernées sont les bonnes

# %% [markdown]
# # Différence des feux entre 2006-2021 et 2022

# %% [markdown]
# *Moyenne en 2022*

# %%
# Filtrer le DataFrame pour ne conserver que les lignes où l'année est 2022
df_2022 = df[df['Année'] == 2022]

# Calculer la somme de la surface parcourue par département en 2022
surface_par_departement_2022 = df_2022.groupby('Département')['Surface parcourue (m2)'].sum().reset_index()

# Renommer les colonnes
surface_par_departement_2022.columns = ['Département', 'Surface_moyenne_2022']

# Convertir la surface de mètres carrés en hectares
surface_par_departement_2022['Surface_hectares_2022'] = surface_par_departement_2022['Surface_moyenne_2022'] / 10000

surface_par_departement_2022.head()  #df avec la moyenne de surface brûlée en 2022 pour chaque département
# Out:
#   Département  Surface_moyenne_2022  Surface_hectares_2022
# 0          01                145000                14.5000
# 1          02                110000                11.0000
# 2          03                    20                 0.0020
# 3          04              13358135              1335.8135
# 4          05                995435                99.5435

# %% [markdown]
# On complète les valeurs manquantes

# %%
surface_par_departement_2022.loc[len(surface_par_departement_2022)] = ['25', 0,0]

# %%
surface_par_departement_2022.loc[len(surface_par_departement_2022)] = ['51', 0,0]

# %%
surface_par_departement_2022.loc[len(surface_par_departement_2022)] = ['75', 0,0]

# %%
surface_par_departement_2022.loc[len(surface_par_departement_2022)] = ['92', 0,0]

# %%
surface_par_departement_2022.loc[len(surface_par_departement_2022)] = ['93', 0,0]

# %%
surface_par_departement_2022.loc[len(surface_par_departement_2022)] = ['94', 0,0]

# %%
dep['Surface_2022'] = 0

# %%
surface_par_departement_2022= surface_par_departement_2022.set_index('Département')

# %%
for i in range(0,96):
    num = dep.loc[i,'INSEE_DEP']
    a = surface_par_departement_2022.loc[num,'Surface_hectares_2022']
    dep.loc[i,'Surface_2022'] = a
# Out:
# /tmp/ipykernel_225/2537370069.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '14.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dep.loc[i,'Surface_2022'] = a

# %%
def couleur_surface(chiffre):
    if chiffre==0:
        return 0
    elif chiffre < 10:
        return 1
    elif chiffre < 100:
        return 2
    elif chiffre < 1000:
        return 3
    elif chiffre < 10000:
        return 4
    else:
        return 5

# %%
dep['categorie_2022']=dep['Surface_2022'].apply(couleur_surface)

from matplotlib.colors import to_rgba
from matplotlib.patches import Patch

# Supposons que "dep" est votre GeoDataFrame et "nb_feu" est la colonne que vous voulez représenter
# Vous pouvez remplacer la colormap par celle de votre choix, par exemple "viridis", "plasma", "inferno", etc.
cmap_name = 'OrRd'

# Définir la plage de valeurs pour la colormap
vmin, vmax = dep['categorie_2022'].min(), dep['categorie_2022'].max()

# Créer la figure et les axes
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

# Utiliser la méthode plot avec l'argument cmap pour personnaliser le gradient de couleurs
plot = dep.plot(column="categorie_2022", cmap=cmap_name, linewidth=0.8, ax=ax, edgecolor='0.8', legend=False, vmin=vmin, vmax=vmax)

# Récupérer les couleurs de la colormap
cmap = plt.cm.get_cmap(cmap_name)
colors = [to_rgba(cmap(i)) for i in range(cmap.N)]

# Personnaliser l'affichage de la légende
legend_labels = ['Absence de données', ']0,10]', ']10,100]', ']100-1000]', ']1000-10000]',']10000,infini]']  # Remplacez par les descriptions de votre choix
legend_patches = [Patch(color=colors[0], label=legend_labels[0]),
                  Patch(color=colors[32], label=legend_labels[1]), Patch(color=colors[96], label=legend_labels[2]), Patch(color=colors[160], label=legend_labels[3]), Patch(color=colors[224], label=legend_labels[4]),Patch(color=colors[255], label=legend_labels[5])]

ax.legend(handles=legend_patches, loc='upper left', title='Nombre de feu')

# Masquer les axes
ax.set_axis_off()

# Ajouter un titre à la carte
plt.title('Surface des feux de forêt en 2022 (en Ha)')

# Afficher la carte
plt.show()
# Out:
# /tmp/ipykernel_225/3191653313.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap_name)

# %% [markdown]
# *Moyenne de 2006 à 2021*

# %%
df['Année'] = pd.to_numeric(df['Année'], errors='coerce')

# Surface annuelle parcourue par département par année 
df_surface_moyenne_par_an = df[df['Année'] <= 2021].groupby(['Département', 'Année'])['Surface parcourue (m2)'].sum().reset_index()

# Renommer les colonnes
df_surface_moyenne_par_an.columns = ['Département', 'Année', 'Moyenne_Surface']

df_surface_moyenne_par_an['Surface_hectares_moyenne'] = df_surface_moyenne_par_an['Moyenne_Surface'] / 10000

# Afficher le nouveau DataFrame avec la moyenne annuelle
print(df_surface_moyenne_par_an.head())
# Out:
#   Département  Année  Moyenne_Surface  Surface_hectares_moyenne
# 0          01   2006           270000                      27.0
# 1          01   2007           165000                      16.5
# 2          01   2008           267000                      26.7
# 3          01   2012           130000                      13.0
# 4          01   2015           130000                      13.0

# %%
# Calculer la moyenne par département des surfaces brûlées de 2006 à 2021 (moyenne des moyennes)
df_moyenne_totale = df_surface_moyenne_par_an.groupby('Département')['Surface_hectares_moyenne'].mean().reset_index()

# Renommer les colonnes
df_moyenne_totale.columns = ['Département', 'Moyenne_Surface']

# Afficher le nouveau DataFrame avec la moyenne par département
print(df_moyenne_totale)
# Out:
#    Département  Moyenne_Surface
# 0           01        21.820000
# 1           02        15.300500
# 2           03        39.711000
# 3           04       144.703213
# 4           05        25.659194
# ..         ...              ...
# 88          91        19.230000
# 89          94         2.000000
# 90          95         0.088333
# 91         974       437.657956
# 92         976       282.692200
#
# [93 rows x 2 columns]

# %%
df_moyenne_totale.loc[len(df_moyenne_totale)] = ['20',0]

# %%
df_moyenne_totale.loc[len(df_moyenne_totale)] = ['44',0]

# %%
df_moyenne_totale.loc[len(df_moyenne_totale)] = ['59',0]

# %%
df_moyenne_totale.loc[len(df_moyenne_totale)] = ['75',0]

# %%
df_moyenne_totale.loc[len(df_moyenne_totale)] = ['92',0]

# %%
df_moyenne_totale.loc[len(df_moyenne_totale)] = ['93',0]

# %%
df_moyenne_totale= df_moyenne_totale.set_index('Département')

# %%
dep['Surface_moyenne_anuelle'] = 0

for i in range(0,96):
    num = dep.loc[i,'INSEE_DEP']
    #print(num)
    a = df_moyenne_totale.loc[num,'Moyenne_Surface']
    #print("la surface de l'incendie était de", a)
    dep.loc[i,'Surface_moyenne_anuelle'] = a
# Out:
# /tmp/ipykernel_225/3153304344.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '21.82' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dep.loc[i,'Surface_moyenne_anuelle'] = a

# %%
def couleur_surface_moyenne(chiffre):
    if chiffre==0:
        return 0
    elif chiffre <= 10:
        return 1
    elif chiffre <= 100:
        return 2
    elif chiffre <= 1000:
        return 3
    elif chiffre <= 1280:
        return 4

# %%
dep['categorie_moyenne']=dep['Surface_moyenne_anuelle'].apply(couleur_surface_moyenne)

from matplotlib.colors import to_rgba
from matplotlib.patches import Patch
# Supposons que "dep" est votre GeoDataFrame et "nb_feu" est la colonne que vous voulez représenter
# Vous pouvez remplacer la colormap par celle de votre choix, par exemple "viridis", "plasma", "inferno", etc.
cmap_name = 'OrRd'

# Définir la plage de valeurs pour la colormap
vmin, vmax = dep['categorie_moyenne'].min(), dep['categorie_moyenne'].max()

# Créer la figure et les axes
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

# Utiliser la méthode plot avec l'argument cmap pour personnaliser le gradient de couleurs
plot = dep.plot(column="categorie_moyenne", cmap=cmap_name, linewidth=0.8, ax=ax, edgecolor='0.8', legend=False, vmin=vmin, vmax=vmax)

# Récupérer les couleurs de la colormap
cmap = plt.cm.get_cmap(cmap_name)
colors = [to_rgba(cmap(i)) for i in range(cmap.N)]

# Personnaliser l'affichage de la légende
legend_labels = ['Aucun feu', ']0-10]', ']10-100]', ']100-1000]', ']1000-1280]']
legend_patches = [Patch(color='gray', label=legend_labels[0]),
                  Patch(color=colors[64], label=legend_labels[1]),
                  Patch(color=colors[128], label=legend_labels[2]),
                  Patch(color=colors[192], label=legend_labels[3]),
                  Patch(color=colors[255], label=legend_labels[4])]

ax.legend(handles=legend_patches, loc='upper left', title='Nombre de feu')

# Masquer les axes
ax.set_axis_off()

# Ajouter un titre à la carte
plt.title('Surface moyenne annuelle des feux de forêt entre 2006 et 2021 (en hA)')

# Afficher la carte
plt.show()
# Out:
# /tmp/ipykernel_225/3402564770.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap(cmap_name)

# %% [markdown]
# ## Feux de forêt le 18 juillet 2022

# %%
df['Date'] = df['Date de première alerte'].str[:10]

# %%
df_juillet = df[df['Date']=='18/07/2022']

# %%
liste2 = df_juillet['Département'].unique().tolist()

# %%
shp_communes2 = s3.download_vectorfile_url_all(
    crs = 4326,
    values = liste2,
    borders="COMMUNE_ARRONDISSEMENT",
    vectorfile_format="topojson",
    filter_by="DEPARTEMENT",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022)
# Out:
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=49/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.02MiB [00:00, 24.9MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=43/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.16MiB [00:00, 58.0MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=71/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.97MiB [00:00, 68.9MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=76/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.48MiB [00:00, 58.7MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=54/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.37MiB [00:00, 45.6MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=67/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.32MiB [00:00, 43.6MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=21/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.88MiB [00:00, 71.3MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=29/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 2.67MiB [00:00, 83.6MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=85/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.56MiB [00:00, 62.3MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=35/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.61MiB [00:00, 55.7MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=44/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.19MiB [00:00, 60.6MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=77/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.57MiB [00:00, 52.6MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=09/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.10MiB [00:00, 58.3MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=90/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 235kiB [00:00, 21.7MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=27/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.14MiB [00:00, 44.2MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=56/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 2.00MiB [00:00, 49.6MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=72/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.40MiB [00:00, 55.4MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=61/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.24MiB [00:00, 40.9MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=70/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.07MiB [00:00, 44.9MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=38/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.49MiB [00:00, 49.3MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=16/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.29MiB [00:00, 42.6MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=79/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.27MiB [00:00, 48.5MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=17/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.79MiB [00:00, 53.5MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=24/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.50MiB [00:00, 42.0MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=40/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.12MiB [00:00, 61.1MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=33/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.47MiB [00:00, 48.1MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=31/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.61MiB [00:00, 64.0MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=41/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 821kiB [00:00, 43.1MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=86/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.00MiB [00:00, 58.4MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=34/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.38MiB [00:00, 20.1MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=11/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.29MiB [00:00, 40.0MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=30/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.14MiB [00:00, 41.9MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=07/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.62MiB [00:00, 41.9MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=13/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 866kiB [00:00, 38.5MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=26/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.18MiB [00:00, 60.7MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=84/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 598kiB [00:00, 45.3MiB/s]
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=57/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 1.64MiB [00:00, 50.6MiB/s]

# %%
villes_touchees = df_juillet['Code INSEE'].unique().tolist()

# %%
len(villes_touchees)
# Out:
# 89

# %%
shp_communes2 = shp_communes2[shp_communes2['INSEE_COM'].isin(villes_touchees)]

# %%
# Spécifiez le chemin du fichier GeoJSON des départements
file_path = 'https://static.data.gouv.fr/resources/carte-des-departements-2-1/20191202-212236/contour-des-departements.geojson'

# Chargez les données géographiques avec GeoPandas
france_departments = gpd.read_file(file_path)

# %%
france_departments.plot()
plt.title('Carte des départements de la France')
shp_communes2.plot(marker='o', color='red', markersize=5, ax=plt.gca())
plt.show()

# %% [markdown]
# ## Ratio surface brulée / surface du département

# %%
dep = s3.download_vectorfile_url_all(
    values = "metropole",
    crs = 4326,
    borders = "DEPARTEMENT",
    vectorfile_format="topojson",
    filter_by="FRANCE_ENTIERE",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022)

dep["area"] = dep.to_crs(2154).area
# Out:
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=DEPARTEMENT/crs=4326/FRANCE_ENTIERE=metropole/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 7.17MiB [00:00, 72.2MiB/s]

# %%
surface = df.groupby('Département')['Surface parcourue (m2)'].sum().reset_index()

# %%
surface = surface.drop(surface.tail(2).index)

# %%
surface.loc[len(surface)] = ['93', 0]

# %%
surface.loc[len(surface)] = ['92', 0]

# %%
surface.loc[len(surface)] = ['75', 0]

# %%
surface = surface.set_index('Département')

# %%
dep['surface_brulee']=0

# %%
for i in range(0, 96):
    num = dep.loc[i, 'INSEE_DEP']
    a = surface.loc[num, 'Surface parcourue (m2)']
    dep.loc[i, 'surface_brulee']=a

# %%
dep['ratio']=dep.apply(lambda row: (row['surface_brulee']/row['area'])*100, axis=1)

# %%
dep['ratio']
# Out:
# 0     0.040299
# 1     0.007670
# 2     3.134566
# 3     4.684133
# 4     0.026957
#         ...
# 91    0.043345
# 92    0.000000
# 93    0.000000
# 94    0.008169
# 95    0.014172
# Name: ratio, Length: 96, dtype: float64

# %%
def categorie(pourcentage):
    if pourcentage == 0:
        return 0
    elif pourcentage <0.5:
        return 1
    elif pourcentage <1:
        return 2
    elif pourcentage <1.5:
        return 3
    elif pourcentage <2:
        return 4
    elif pourcentage <2.5:
        return 5
    elif pourcentage <3:
        return 6
    elif pourcentage <3.5:
        return 7
    elif pourcentage<4:
        return 8
    else:
        return 9

# %%
cmap = 'YlOrRd'

# Définir la plage de valeurs pour la colormap
vmin, vmax = dep['ratio'].min(), dep['ratio'].max()

# Créer la figure et les axes
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Utiliser la méthode plot avec l'argument cmap pour personnaliser le gradient de couleurs
ax = dep.plot(column="ratio", cmap=cmap, linewidth=0.8, ax=ax, edgecolor='0.8', legend=True, vmin=vmin, vmax=vmax)

for idx, row in dep.iterrows():
    if row['ratio']>0.5:
        ax.annotate(text=f"{row['ratio']:.2f}", xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                    color='black', fontsize=8, ha='center')

# Ajouter un titre à la carte
plt.title('Ration surface brulee / surface du département')

# Afficher la carte
plt.show()

# %% [markdown]
# ## Nombre de grands feux (>20 hectares)

# %%
df_grands_feux = df[df['Surface parcourue (m2)'] > 20*10000]

# %%
dep = s3.download_vectorfile_url_all(
    values = "metropole",
    crs = 4326,
    borders = "DEPARTEMENT",
    vectorfile_format="topojson",
    filter_by="FRANCE_ENTIERE",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022)

dep["area"] = dep.to_crs(2154).area
# Out:
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=DEPARTEMENT/crs=4326/FRANCE_ENTIERE=metropole/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 7.17MiB [00:00, 62.3MiB/s]

# %%
dep['nb_feu']=0

# %%
counts = df_grands_feux['Département'].value_counts().to_frame().reset_index()

# %%
non_concernes = ['75', '92', '93', '02', '08', '14', '22', '51', '53', '59', '62', '67', '68', '70', '77', '78', '80', '90', '94', '95']

# %%
for d in non_concernes:
    counts.loc[len(counts)]=[d, 0]

# %%
counts = counts.set_index('Département')

# %%
for i in range(0, 96):
    num = dep.loc[i, 'INSEE_DEP']
    a = counts.loc[num, 'count']
    dep.loc[i, 'nb_feu']=a

# %%
cmap = 'YlOrRd'

# Définir la plage de valeurs pour la colormap
vmin, vmax = dep['nb_feu'].min(), dep['nb_feu'].max()

# Créer la figure et les axes
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Utiliser la méthode plot avec l'argument cmap pour personnaliser le gradient de couleurs
ax = dep.plot(column="nb_feu", cmap=cmap, linewidth=0.8, ax=ax, edgecolor='0.8', legend=True, vmin=vmin, vmax=vmax)

for idx, row in dep.iterrows():
    if row['nb_feu']>25:
        ax.annotate(text=f"{row['nb_feu']:.2f}", xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                    color='black', fontsize=8, ha='center')

# Ajouter un titre à la carte
plt.title('Nombre de grands feux par département (plus de 20 hectares)')

# Afficher la carte
plt.show()

# %% [markdown]
# ## Nombre de très grand feux (>100 hectares)

# %%
df_tgrands_feux = df[df['Surface parcourue (m2)'] > 100*10000]

# %%
dep = s3.download_vectorfile_url_all(
    values = "metropole",
    crs = 4326,
    borders = "DEPARTEMENT",
    vectorfile_format="topojson",
    filter_by="FRANCE_ENTIERE",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022)

dep["area"] = dep.to_crs(2154).area
# Out:
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=DEPARTEMENT/crs=4326/FRANCE_ENTIERE=metropole/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 7.17MiB [00:00, 76.3MiB/s]

# %%
dep['nb_feu']=0

# %%
counts = df_tgrands_feux['Département'].value_counts().to_frame().reset_index()

# %%
counts = counts.set_index('Département')

# %%
for i in range(0, 96):
    num = dep.loc[i, 'INSEE_DEP']
    try:
        a = counts.loc[num, 'count']
    except KeyError:  # Gérer l'exception si num n'est pas dans counts
        a = 0
    dep.loc[i, 'nb_feu'] = a

# %%
cmap = 'YlOrRd'

# Définir la plage de valeurs pour la colormap
vmin, vmax = dep['nb_feu'].min(), dep['nb_feu'].max()

# Créer la figure et les axes
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Utiliser la méthode plot avec l'argument cmap pour personnaliser le gradient de couleurs
ax = dep.plot(column="nb_feu", cmap=cmap, linewidth=0.8, ax=ax, edgecolor='0.8', legend=True, vmin=vmin, vmax=vmax)

for idx, row in dep.iterrows():
    if row['nb_feu']>7:
        ax.annotate(text=f"{row['nb_feu']:.2f}", xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                    color='black', fontsize=8, ha='center')

# Ajouter un titre à la carte
plt.title('Nombre de très grands feux par département (plus de 100 hectares)')

# Afficher la carte
plt.show()
